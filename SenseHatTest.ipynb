# %%
# import packages 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Optional - Set figure resolution to 300dpi
import matplotlib as mpl
# %matplotlib inline
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %% [markdown]
# ## Just testing out the Sense Hat by picking up the Raspberry pi and moving it around for a few seconds

# %%
df = pd.read_csv (r'./data.csv', index_col=13) 
df
# Out:
#           temp     pres    hum  mag_x  mag_y  mag_z  acc_x  acc_y  acc_z  \
# elapsed
# 2566     40.47  1004.72  30.18   1.51  -4.51   5.52  0.014  0.006  1.006
# 2708     40.68  1004.71  30.79   7.30 -19.82  23.60  0.009  0.012  0.999
# 2843     40.49  1004.72  30.53  10.77 -19.17  25.91  0.009  0.010  0.999
# 2970     40.66  1004.71  30.14  11.11 -19.11  26.32  0.009  0.010  0.999
# 3107     40.59  1004.71  29.69  10.64 -19.18  25.10  0.008  0.011  0.999
# ...        ...      ...    ...    ...    ...    ...    ...    ...    ...
# 12412    40.59  1004.72  30.91  14.54 -11.40  24.78 -0.131  0.144  0.731
# 12555    40.51  1004.72  31.06  -6.63  10.33  20.73 -0.779  1.113 -0.288
# 12688    40.47  1004.72  30.36 -14.78  19.94  15.37 -0.539  0.608  0.457
# 12833    40.57  1004.73  31.12   1.23   0.04  25.28  0.210 -0.468  1.092
# 12960    40.55  1004.72  30.55  11.13  -9.74  27.52  0.168 -0.242  1.106
#
#           pitch   roll     yaw                    datetime
# elapsed
# ...

# %% [markdown]
# #### A look at the total data collected:

# %%
df.plot.line(marker = 'o')
# Out:
# <Axes: xlabel='elapsed'>

# %% [markdown]
# #### Now to looks at some specifics:

# %%
fig, ax = plt.subplots()
df.plot.line(ax = ax, y = 'pitch',color = 'r', marker = 'o')
df.plot.line(ax = ax, y = 'roll',color = 'b', marker = 'o')
df.plot.line(ax = ax, y = 'yaw',color = 'y', marker = 'o')
ax.set_xlabel("Time (msec)")
ax.set_ylabel("Angle ($^\circ$)")
plt.title('Orientation over time')
# Out:
# Text(0.5, 1.0, 'Orientation over time')

# %%
fig, ax = plt.subplots()
df.plot.line(ax = ax, y = 'acc_x',color = 'r', marker = 'o')
df.plot.line(ax = ax, y = 'acc_y',color = 'b', marker = 'o')
df.plot.line(ax = ax, y = 'acc_z',color = 'y', marker = 'o')
ax.set_xlabel("Time (msec)")
ax.set_ylabel("Acceleration (g)")
plt.title('Acceleration over time')
# Out:
# Text(0.5, 1.0, 'Acceleration over time')

# %%
fig, ax = plt.subplots()
df.plot.line(ax = ax, y = 'hum',color = 'r', marker = 'o')
ax.set_xlabel("Time (msec)")
ax.set_ylabel("%")
plt.title('Humidity over time')
# Out:
# Text(0.5, 1.0, 'Humidity over time')

# %%
fig, ax = plt.subplots()
df.plot.line(ax = ax, y = 'temp',color = 'r', marker = 'o')
ax.set_xlabel("Time (msec)")
ax.set_ylabel("$^\circ$C")
plt.title('Temperature over time')
# Out:
# Text(0.5, 1.0, 'Temperature over time')

# %%
fig, ax = plt.subplots()
df.plot.line(ax = ax, y = 'pres',color = 'r', marker = 'o')
ax.set_xlabel("Time (msec)")
ax.set_ylabel("millibars")
plt.ticklabel_format(useOffset=False)
plt.title('Pressure over time')
# Out:
# Text(0.5, 1.0, 'Pressure over time')

# %% [markdown]
# ## Comparative control: Recording while not moving (although I did bump the table a little bit)

# %%
df2 = pd.read_csv (r'./data (1).csv', index_col=13) 
df2
# Out:
#           temp     pres    hum  mag_x  mag_y  mag_z  acc_x  acc_y  acc_z  \
# elapsed
# 4923     46.40  1005.08  25.48   3.02  -3.06   5.32  0.008  0.008  0.994
# 5061     46.40  1005.08  26.07  13.49 -13.74  22.15  0.007  0.006  0.994
# 5187     46.46  1005.09  24.92  16.04 -13.89  23.93  0.008  0.008  0.994
# 5321     46.44  1005.09  24.36  16.51 -14.35  23.49  0.008  0.007  0.993
# 5464     46.46  1005.09  25.20  16.09 -14.39  24.17  0.008  0.006  0.994
# ...        ...      ...    ...    ...    ...    ...    ...    ...    ...
# 14653    46.50  1005.09  25.12  15.37 -13.91  23.46  0.010  0.007  0.995
# 14790    46.40  1005.10  25.58  15.78 -14.07  24.02  0.007  0.007  0.996
# 14931    46.48  1005.09  26.26  15.64 -13.86  23.35  0.008  0.006  0.994
# 15083    46.55  1005.10  24.44  15.89 -14.20  23.16  0.011  0.008  0.996
# 15235    46.42  1005.10  24.78  15.75 -14.00  22.71  0.008  0.008  0.995
#
#           pitch  roll    yaw                    datetime
# elapsed
# ...

# %% [markdown]
# #### A look at the total data collected:

# %%
df2.plot.line(marker = 'o')
# Out:
# <Axes: xlabel='elapsed'>

# %% [markdown]
# #### Now to looks at some specifics:

# %%
fig, ax = plt.subplots()
df2.plot.line(ax = ax, y = 'pitch',color = 'r', marker = 'o')
df2.plot.line(ax = ax, y = 'roll',color = 'b', marker = 'o')
df2.plot.line(ax = ax, y = 'yaw',color = 'y', marker = 'o')
ax.set_xlabel("Time (msec)")
ax.set_ylabel("Angle ($^\circ$)")
plt.title('Orientation over time')
# Out:
# Text(0.5, 1.0, 'Orientation over time')

# %%
fig, ax = plt.subplots()
df2.plot.line(ax = ax, y = 'acc_x',color = 'r', marker = 'o')
df2.plot.line(ax = ax, y = 'acc_y',color = 'b', marker = 'o')
df2.plot.line(ax = ax, y = 'acc_z',color = 'y', marker = 'o')
ax.set_xlabel("Time (msec)")
ax.set_ylabel("Acceleration (g)")
plt.title('Acceleration over time')
# Out:
# Text(0.5, 1.0, 'Acceleration over time')

# %%
fig, ax = plt.subplots()
df2.plot.line(ax = ax, y = 'hum',color = 'r', marker = 'o')
ax.set_xlabel("Time (msec)")
ax.set_ylabel("%")
plt.title('Humidity over time')
# Out:
# Text(0.5, 1.0, 'Humidity over time')

# %%
fig, ax = plt.subplots()
df2.plot.line(ax = ax, y = 'temp',color = 'r', marker = 'o')
ax.set_xlabel("Time (msec)")
ax.set_ylabel("$^\circ$C")
plt.title('Temperature over time')
# Out:
# Text(0.5, 1.0, 'Temperature over time')

# %%
fig, ax = plt.subplots()
df2.plot.line(ax = ax, y = 'pres',color = 'r', marker = 'o')
ax.set_xlabel("Time (msec)")
ax.set_ylabel("millibars")
plt.ticklabel_format(useOffset=False)
plt.title('Pressure over time')
# Out:
# Text(0.5, 1.0, 'Pressure over time')
